% %% [markdown]
% ### The goal of this XP:
% Create a outline image for functional QC in zooniverse platform - Brain Match
% 1. Create functionl brain border outline
% 2. Assemnble left/right funtional brain layout
% 3. Merge all Layout
% 3. Visualise in a montage

% %%
clear all
% build path
addpath(genpath('../Misc'))
build_path  niak psom zooniverse_qc
% Out:
% error: 'build_path' undefined near line 1 column 1

% %%
addpath(genpath('../Misc'))

% %% [markdown]
% ### First create brain outlines

% %%
# Set path
path_root = '../data/Misc/landmarks/';
path_outline = [path_root 'brain_outline_bold/'];
path_layout = path_root ;

% %%
# Reshape 
command_reshape = ['mincresample -clobber ' path_outline 'func_mask_average_stereonl.mnc.gz ' ...
path_outline 'func_mask_average_stereonl_1mm.mnc -like ' path_outline ...
'mni_icbm152_t1_tal_nlin_asym_09a_mask_dilated5mm.mnc.gz -trilinear'];
system(command_reshape);
[hdr,avg_mask_bold] = niak_read_vol([path_outline 'func_mask_average_stereonl_1mm.mnc']);
[hdr,mask_t1] = niak_read_vol([path_outline 'mni_icbm152_t1_tal_nlin_asym_09a_mask.mnc.gz']);
% Out:
% Transforming slices:.............................................................................................................................................................................................Done

% %%
niak_montage(avg_mask_bold)

% %%
niak_montage(mask_t1)

% %%
# Create brain border mask
mask_t1_d = niak_morph(mask_t1,'-successive DDD');
bold_in = avg_mask_bold>0.99;
%bold_out = (avg_mask_bold>0)&~bold_in;
bold_outline = ~bold_in&mask_t1_d;
%mask = bold_out | t1_out;
hdr.file_name = [path_outline 'mask_outline_brain_bold.mnc.gz'];
niak_write_vol(hdr,bold_outline);
% Out:
% mv: failed to preserve ownership for '../data/Misc/landmarks/brain_outline_bold/mask_outline_brain_bold.mnc.gz': Permission denied

% %%
niak_montage(bold_outline)

% %% [markdown]
% ### Second assemble brain layout

% %%
# List layout
list_layout = {(dir([path_layout 'left_*.nii.gz'])).name}
% Out:
% list_layout =
% {
%   [1,1] = left_calcarine_sulcus.nii.gz
%   [1,2] = left_central_sulcus.nii.gz
%   [1,3] = left_cingulate_sulcus.nii.gz
%   [1,4] = left_hippocampal_formation.nii.gz
%   [1,5] = left_parieto-occipital_fissure.nii.gz
%   [1,6] = left_tentorium_cerebelli.nii.gz
%   [1,7] = left_ventricul.nii.gz
% }

% %%
# liasst exclude for BOLD
#list_exclude = {'left_cingulate_sulcus.nii.gz','left_ventricul.nii.gz'};
#list_layout = list_layout(~ismember(list_layout,list_exclude))

% %%
# Assemble left right layout volume
[hdr,vol] = niak_read_vol ([path_root '/mni_icbm152_gm_tal_nlin_sym_09a.nii.gz']);
vol_final = zeros(size(vol));
for ii=1:length(list_layout)
    fprintf('%s\n',list_layout{ii}(6:end-7))
    [hdr,mask] = niak_read_vol ([path_layout list_layout{ii}]);
    vol_raw = vol;
    vol_raw(mask==0) = 0;
    region = sprintf('%s',list_layout{ii}(6:end-7));
    switch region
        case {'ventricul'}
        vol_t = vol_raw>0.1; 
        case {'calcarine_sulcus'}
        vol_t = vol_raw>0.6;
        case {'tentorium_cerebelli'}
        vol_t = vol_raw>0.5;
        case {'central_sulcus' , 'cingulate_sulcus' , 'hippocampal_formation' , 'parieto-occipital_fissure'}
        vol_t = vol_raw>0.2;
    end   
    hdr.file_name = [path_layout 'mask_layout/mask_' list_layout{ii}] ;
    niak_write_vol (hdr,vol_t);
    hdr.file_name = [path_layout 'mask_layout/mask_right' list_layout{ii}(5:end)];
    vol_transpose = vol_t(end:-1:1,:,:);
    niak_write_vol (hdr,vol_transpose);
    vol_final = vol_final |vol_t | vol_transpose;
end
% Out:
% calcarine_sulcus
% mv: failed to preserve ownership for '../data/Misc/landmarks/mask_layout/mask_left_calcarine_sulcus.nii.gz': Permission denied
% mv: failed to preserve ownership for '../data/Misc/landmarks/mask_layout/mask_right_calcarine_sulcus.nii.gz': Permission denied
% central_sulcus
% mv: failed to preserve ownership for '../data/Misc/landmarks/mask_layout/mask_left_central_sulcus.nii.gz': Permission denied
% mv: failed to preserve ownership for '../data/Misc/landmarks/mask_layout/mask_right_central_sulcus.nii.gz': Permission denied
% cingulate_sulcus
% mv: failed to preserve ownership for '../data/Misc/landmarks/mask_layout/mask_left_cingulate_sulcus.nii.gz': Permission denied
% mv: failed to preserve ownership for '../data/Misc/landmarks/mask_layout/mask_right_cingulate_sulcus.nii.gz': Permission denied
% hippocampal_formation
% mv: failed to preserve ownership for '../data/Misc/landmarks/mask_layout/mask_left_hippocampal_formation.nii.gz': Permission denied
% mv: failed to preserve ownership for '../data/Misc/landmarks/mask_layout/mask_right_hippocampal_formation.nii.gz': Permission denied
% parieto-occipital_fissure
% mv: failed to preserve ownership for '../data/Misc/landmarks/mask_layout/mask_left_parieto-occipital_fissure.nii.gz': Permission denied
% mv: failed to preserve ownership for '../data/Misc/landmarks/mask_layout/mask_right_parieto-occipital_fissure.nii.gz': Permission denied
% tentorium_cerebelli
% mv: failed to preserve ownership for '../data/Misc/landmarks/mask_layout/mask_left_tentorium_cerebelli.nii.gz': Permission denied
% mv: failed to preserve ownership for '../data/Misc/landmarks/mask_layout/mask_right_tentorium_cerebelli.nii.gz': Permission denied
% ventricul
% mv: failed to preserve ownership for '../data/Misc/landmarks/mask_layout/mask_left_ventricul.nii.gz': Permission denied
% mv: failed to preserve ownership for '../data/Misc/landmarks/mask_layout/mask_right_ventricul.nii.gz': Permission denied

% %%
% write layout
hdr.file_name = [path_layout 'layout_anat.nii.gz'];
% smooth landmarks
vol_final_s = niak_morph (vol_final,'-successive DDEE');
niak_write_vol (hdr,vol_final_s);
niak_montage(vol_final_s)
% Out:
% mv: failed to preserve ownership for '../data/Misc/landmarks/layout_anat.nii.gz': Permission denied

% %% [markdown]
% ### Crate montage image

% %%
clear jin jout jopt
% Input
niak_gb_vars
jin.source =[path_layout 'layout_anat.nii.gz'];
%jin.source =[path_layout 'mask_layout/mask_all_layout_v2_smoothed.nii.gz'];
jin.target = [ GB_NIAK.path_niak filesep 'template' filesep 'mni-models_icbm152-nl-2009-1.0' filesep ...
'mni_icbm152_t1_tal_nlin_sym_09a.mnc.gz'];

% Output
jout = [path_layout 'mask_layout/landmarks_smoothed.png'];

% Options
jopt.colormap = 'jet';
jopt.colorbar = false;
jopt.flag_decoration = false;
jopt.limits = [0 1.1];
jopt.coord =[-50 , -65 , -6 ;
             -8 , -20 , 13 ;
             30 , 54 , 58];
             
% The generation of the montage itself
niak_brick_vol2img(jin,jout,jopt);
imshow(jout)

% %% [markdown]
% ### Merge all layout

% %%
% write final volume layout
vol_final = vol_final | bold_outline;
hdr.file_name = [path_layout 'mask_layout/mask_all_layout_v2.nii.gz'];
niak_write_vol (hdr,vol_final);

% smooth final volume layout
vol_final_s = niak_morph (vol_final,'-successive DDDDEEEE');
niak_montage (vol_final_s)
hdr.file_name =  [path_layout 'mask_layout/mask_all_layout_v2_smoothed.nii.gz'];
niak_write_vol (hdr,vol_final_s);
% Out:
% mv: failed to preserve ownership for '../data/Misc/landmarks/mask_layout/mask_all_layout_v2.nii.gz': Permission denied
% mv: failed to preserve ownership for '../data/Misc/landmarks/mask_layout/mask_all_layout_v2_smoothed.nii.gz': Permission denied

% %% [markdown]
% ### Create montage of bold layout

% %%
clear jin jout jopt
% Input
niak_gb_vars
jin.source =[path_layout 'layout_anat.nii.gz'];
%jin.source =[path_layout 'mask_layout/mask_all_layout_v2_smoothed.nii.gz'];
jin.target = [ GB_NIAK.path_niak filesep 'template' filesep 'mni-models_icbm152-nl-2009-1.0' filesep ...
'mni_icbm152_t1_tal_nlin_sym_09a.mnc.gz'];

% Output
jout = [path_layout 'mask_layout/landmarks_smoothed.png'];

% Options
jopt.colormap = 'jet';
jopt.colorbar = false;
jopt.flag_decoration = false;
jopt.limits = [0 1.1];
jopt.coord =[-50 , -65 , -6 ;
             -8 , -20 , 13 ;
             30 , 54 , 58];
             
% The generation of the montage itself
niak_brick_vol2img(jin,jout,jopt);
imshow(jout)

% %%
jin.source
% Out:
% ans = /home/yassinebha/Drive/QC_zooniverse/template_layout/layout/mask_layout/mask_all_layout_v2_smoothed.nii.gz
